# %% [markdown]
# ## Analisis from Bitcoin and Dollar historical data

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from matplotlib import dates as mpl_dates

# %%
btcDataset = pd.read_csv('../Data/BTC-BRL/2019.csv')
usdDataset = pd.read_csv('../Data/USD-BRL/dez2019.csv')

# %%
btcDataset.head()
# Out:
#          date     close      open       max       min volume variation
# 0  31.12.2019  29.201,1  29.699,9  29.999,8  29.057,0  0,08K    -1,68%
# 1  30.12.2019  29.699,9  29.820,0  30.200,0  29.400,0  0,17K    -0,40%
# 2  29.12.2019  29.820,0  29.775,0  30.210,0  29.560,5  0,03K     0,15%
# 3  28.12.2019  29.775,0  29.560,0  29.889,0  29.560,0  0,04K     0,73%
# 4  27.12.2019  29.560,0  29.600,0  29.894,4  29.033,0  0,15K    -0,14%

# %%
usdDataset.head()
# Out:
#          date   close    open    high     low variation
# 0  31-12-2019  4,0195  4,0201  4,0201  4,0195     0,00%
# 1  30-12-2019  4,0195  4,0484  4,0484  4,0084    -0,65%
# 2  27-12-2019  4,0460  4,0568  4,0614  4,0339    -0,25%
# 3  26-12-2019  4,0560  4,0827  4,0827  4,0453    -0,68%
# 4  25-12-2019  4,0838  4,0838  4,0838  4,0838     0,00%

# %%
plt.style.use('seaborn')
price_date = usdDataset['date']
price_close = usdDataset['close']
plt.plot_date(price_date, price_close, linestyle='solid')

# %% [markdown]
# ### Dataset

# %%
from sklearn import datasets

# %% [markdown]
# ### K-Nearest Neighbours

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5, 
                           weights="uniform", 
                           algorithm="auto", 
                           leaf_size=30, 
                           p=2, 
                           metric="minkowski", 
                           metric_params=None, 
                           n_jobs=1)

plot_result(X, y, knn, "K-Nearest Neighbours")
